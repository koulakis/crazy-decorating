# %% [markdown]
# # Resize images

# %%
from skimage.io import imread
from skimage.transform import resize
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def resize_images(input_dir, output_dir, size):
    filenames = os.listdir(input_dir)
    
    for filename in filenames:
        image_name = filename.split('.')[0]
        try:
            image = imread(os.path.join(input_dir, filename))
            save_path = os.path.join(output_dir, '{}.npy'.format(image_name))
            np.save(
                save_path, 
                resize(image, size))
        except Exception as e:
            print(e)
            print(image_name.split('_')[1])

# %%
widths = []

for filename in paths:
    try:
        image = imread(filename)
        widths.append(image.shape[0])
    except:
        print(filename)
# Out:
# (800, 800, 3)
# (3436, 2516, 3)
# (1024, 579, 3)
# (400, 400, 3)
# (683, 1024, 3)
# (496, 694, 3)
# (800, 800, 3)
# (800, 800, 3)
# (350, 350, 3)
# (1000, 1500, 3)
# (800, 800, 3)
# (800, 800, 3)
# (367, 550, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (367, 550, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (683, 1024, 3)
# (800, 800, 3)
# (800, 800, 3)
# (720, 720, 3)
# (664, 650, 3)
# ../data/validation/pic_6192.png
# (1000, 1000, 3)
# (490, 600, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (380, 380, 3)
# (350, 350, 3)
# (700, 700, 3)
# (313, 313, 3)
# (300, 300, 3)
# (900, 1200, 3)
# (381, 280, 3)
# (400, 400, 3)
# (800, 800, 3)
# (300, 300, 3)
# (800, 800, 3)
# (400, 600, 3)
# (800, 800, 3)
# (436, 550, 3)
# (1282, 1282, 3)
# (800, 890, 3)
# (700, 700, 3)
# (383, 720, 3)
# (480, 640, 3)
# (800, 800, 3)
# (750, 750, 3)
# (800, 800, 3)
# (800, 800, 3)
# (750, 750, 3)
# (800, 800, 3)
# (845, 900, 3)
# (430, 430, 3)
# (800, 800, 3)
# (720, 800, 3)
# (690, 292, 3)
# (800, 800, 3)
# ../data/validation/pic_5675.png
# (1099, 700, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (450, 600, 3)
# (353, 350, 3)
# (800, 800, 3)
# (748, 1064, 3)
# (800, 800, 3)
# (1000, 666, 3)
# (1767, 1920, 3)
# (769, 566, 3)
# (800, 800, 3)
# (800, 800, 3)
# (360, 360, 3)
# (800, 800, 3)
# (420, 420, 3)
# (800, 800, 3)
# (800, 800, 3)
# (6, 453, 790, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (450, 600, 3)
# (750, 750, 3)
# (488, 755, 4)
# (800, 800, 3)
# (1000, 1000, 3)
# (328, 450, 3)
# (332, 367, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (405, 550, 3)
# (800, 800, 3)
# (617, 1024, 3)
# (320, 320, 3)
# (800, 800, 3)
# (560, 440, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (1000, 1000, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (2160, 3840, 3)
# (1920, 1436, 3)
# (290, 290, 3)
# ../data/validation/pic_6322.png
# ../data/validation/pic_3015.png
# ../data/validation/pic_5233.png
# (432, 720, 3)
# (471, 788, 3)
# (800, 800, 3)
# (320, 440, 3)
# (800, 800, 3)
# (672, 750, 3)
# (517, 780, 3)
# (800, 800, 3)
# (360, 360, 3)
# (800, 800, 3)
# (563, 433, 3)
# (430, 430, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (652, 1150, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (480, 640, 3)
# (800, 800, 3)
# (765, 800, 3)
# (920, 1000, 3)
# (990, 990, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 1210, 3)
# (310, 310, 3)
# (800, 800, 3)
# (310, 310, 3)
# (662, 640, 3)
# (800, 800, 3)
# (297, 300, 3)
# (683, 1024, 3)
# (800, 800, 3)
# (800, 800, 3)
# (400, 366, 3)
# (800, 800, 3)
# (600, 600, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (300, 300, 3)
# (900, 900, 3)
# (2334, 1804, 3)
# (800, 800, 3)
# (750, 750, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (1320, 1920, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (643, 1024, 3)
# (311, 326, 3)
# (800, 800, 3)
# (379, 400, 3)
# (800, 800, 3)
# ../data/validation/pic_1065.png
# (1200, 1200, 3)
# (800, 800, 3)
# (800, 800, 3)
# (1178, 1920, 3)
# ../data/validation/pic_4339.png
# (800, 800, 3)
# (524, 730, 3)
# (450, 600, 3)
# (800, 800, 3)
# ../data/validation/pic_1686.png
# (800, 800, 3)
# (565, 500, 3)
# (636, 848, 3)
# (800, 800, 3)
# (1500, 1500, 3)
# (487, 650, 3)
# (800, 800, 3)
# (500, 750, 3)
# (750, 750, 3)
# (800, 800, 3)
# (780, 1052, 3)
# (270, 270, 3)
# (800, 800, 3)
# (1024, 1024, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (322, 426, 3)
# (400, 400, 3)
# (800, 800, 3)
# (800, 800, 3)
# (420, 420, 3)
# (800, 800, 3)
# (700, 465, 3)
# (400, 400, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 1018, 3)
# (350, 400, 3)
# (715, 717, 4)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (690, 750, 3)
# (800, 800, 3)
# ../data/validation/pic_5539.png
# (800, 800, 3)
# (800, 800, 3)
# (480, 480, 3)
# (800, 800, 3)
# (800, 800, 3)
# (797, 1200, 3)
# (600, 450, 3)
# ../data/validation/pic_5861.png
# (800, 800, 3)
# (860, 1240, 3)
# (780, 780, 3)
# (1, 1)
# (595, 559, 3)
# (800, 800, 3)
# (700, 1000, 3)
# (800, 800, 3)
# (700, 700, 3)
# (800, 800, 3)
# (604, 421, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (500, 500, 3)
# (640, 1138, 3)
# (310, 310, 3)
# (800, 800, 3)
# (800, 800, 3)
# (600, 360, 3)
# ../data/validation/pic_4741.png
# (373, 605, 3)
# (800, 800, 3)
# (420, 600, 3)
# (517, 690, 3)
# ../data/validation/pic_5503.png
# (742, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (469, 750, 3)
# (320, 320, 3)
# (909, 909, 3)
# (800, 800, 3)
# (14, 520, 750, 3)
# (308, 560, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (266, 388, 3)
# (800, 800, 3)
# (430, 430, 3)
# (310, 310, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# ../data/validation/pic_5036.png
# (736, 800, 3)
# (800, 800, 3)
# (406, 400, 3)
# (720, 720, 3)
# (974, 1300, 3)
# (800, 800, 3)
# (460, 460, 3)
# (800, 800, 3)
# ../data/validation/pic_5222.png
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (750, 750, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (310, 310, 3)
# (472, 677, 3)
# (800, 800, 3)
# (800, 800, 3)
# (750, 750, 3)
# (511, 800, 3)
# (447, 550, 3)
# (800, 800, 3)
# (310, 310, 3)
# (400, 400, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (744, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (879, 790, 3)
# (800, 800, 3)
# (323, 694, 3)
# (800, 800, 3)
# (310, 310, 3)
# (285, 500, 3)
# (800, 800, 3)
# (600, 600, 3)
# (310, 310, 3)
# (310, 310, 3)
# (401, 500, 3)
# (800, 800, 3)
# (460, 460, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (310, 310, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (310, 310, 3)
# (792, 1000, 3)
# (276, 300, 3)
# (800, 800, 3)
# (300, 300, 3)
# (800, 800, 3)
# (500, 500, 3)
# (800, 800, 3)
# (310, 310, 3)
# (1200, 1200, 3)
# (800, 800, 3)
# (800, 800, 3)
# (600, 600, 3)
# (300, 300, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (310, 310, 3)
# (800, 800, 3)
# (800, 800, 3)
# (750, 750, 3)
# (399, 400, 3)
# (800, 800, 3)
# (800, 800, 3)
# (900, 1200, 3)
# (800, 800, 3)
# (599, 650, 3)
# (426, 600, 3)
# (633, 590, 3)
# (669, 1000, 3)
# (476, 771, 3)
# (800, 800, 3)
# (800, 800, 3)
# (1000, 1000, 3)
# (800, 800, 3)
# (800, 800, 3)
# (750, 750, 3)
# (800, 800, 3)
# (800, 800, 3)
# (288, 433, 3)
# (700, 1000, 3)
# (498, 603, 3)
# (601, 393, 3)
# (460, 460, 3)
# (800, 800, 3)
# (640, 640, 3)
# (346, 520, 3)
# (600, 600, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (1492, 1500, 3)
# ../data/validation/pic_157.png
# (700, 700, 3)
# (571, 800, 3)
# (800, 800, 3)
# (367, 550, 3)
# (790, 790, 3)
# (542, 673, 3)
# (400, 400, 3)
# (800, 800, 3)
# (800, 800, 3)
# (348, 450, 3)
# (800, 800, 3)
# (350, 350, 3)
# (800, 800, 3)
# (800, 800, 3)
# (300, 300, 3)
# (750, 750, 3)
# (800, 800, 3)
# (287, 469, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# ../data/validation/pic_4841.png
# (403, 460, 3)
# (380, 480, 3)
# (3731, 3731, 3)
# (800, 800, 3)
# (430, 430, 3)
# (300, 300, 3)
# (800, 800, 3)
# (542, 980, 3)
# (800, 800, 3)
# (800, 800, 3)
# (956, 750, 3)
# (734, 1024, 3)
# (800, 800, 3)
# (800, 800, 3)
# (900, 900, 3)
# (390, 482, 3)
# (800, 800, 3)
# (800, 800, 3)
# (320, 500, 3)
# (750, 750, 3)
# (280, 500, 3)
# (800, 800, 3)
# (400, 400, 3)
# (350, 350, 3)
# (800, 800, 3)
# (1024, 649, 3)
# (750, 750, 3)
# (800, 800, 3)
# ../data/validation/pic_4748.png
# (800, 800, 3)
# (800, 800, 3)
# (1920, 1671, 3)
# (350, 350, 3)
# (800, 800, 3)
# (800, 800, 3)
# (310, 310, 3)
# (310, 310, 3)
# (591, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 4)
# (639, 427, 3)
# (341, 338, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (380, 380, 3)
# (800, 800, 4)
# (800, 800, 3)
# (630, 800, 3)
# (800, 800, 3)
# (530, 600, 3)
# (516, 800, 3)
# (511, 717, 3)
# (500, 500, 3)
# (3451, 5198, 3)
# (800, 1200, 3)
# (800, 800, 3)
# (442, 600, 3)
# (800, 800, 3)
# (629, 790, 3)
# (640, 795, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (2265, 2268, 3)
# (800, 800, 3)
# (800, 800, 3)
# (1079, 960, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (500, 500, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (307, 400, 3)
# (1390, 1100, 3)
# (320, 480, 3)
# (569, 750, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (1390, 1100, 3)
# (800, 800, 3)
# (800, 800, 3)
# (338, 450, 3)
# (350, 350, 3)
# (800, 800, 3)
# (502, 750, 3)
# (300, 300, 3)
# (545, 650, 3)
# (331, 400, 3)
# (460, 750, 3)
# (757, 800, 3)
# (800, 800, 3)
# (1380, 1500, 3)
# (357, 403, 3)
# (429, 600, 3)
# (739, 739, 3)
# (750, 750, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (1024, 1024, 3)
# (400, 400, 3)
# (800, 800, 3)
# (700, 700, 3)
# (800, 800, 3)
# (419, 450, 3)
# (800, 800, 3)
# (736, 800, 3)
# (326, 513, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (720, 1280, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (400, 600, 3)
# (800, 800, 3)
# (600, 800, 3)
# (310, 310, 3)
# (800, 800, 3)
# (400, 400, 3)
# (302, 486, 3)
# (800, 800, 3)
# (361, 304, 3)
# (800, 800, 3)
# (443, 612, 3)
# (800, 800, 3)
# (345, 560, 3)
# (800, 800, 3)
# (479, 520, 3)
# ../data/validation/pic_1185.png
# (800, 800, 3)
# (600, 700, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (1000, 1000, 3)
# (800, 800, 3)
# (613, 650, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (290, 290, 3)
# (800, 800, 3)
# (500, 500, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (263, 280, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (600, 450, 3)
# (800, 800, 3)
# (460, 460, 3)
# (800, 800, 3)
# (2835, 2835, 3)
# (332, 544, 4)
# (492, 287, 3)
# (480, 720, 3)
# (400, 400, 3)
# (800, 800, 3)
# (460, 460, 3)
# (800, 800, 3)
# (800, 800, 3)
# (627, 1024, 3)
# (572, 500, 3)
# (800, 800, 3)
# (482, 720, 3)
# (567, 750, 3)
# (800, 800, 3)
# (800, 800, 3)
# (700, 700, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (917, 1000, 3)
# (300, 400, 3)
# (800, 800, 3)
# (310, 630, 3)
# (800, 800, 3)
# (750, 750, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 4)
# (600, 600, 3)
# (800, 800, 3)
# (800, 800, 3)
# (593, 591, 3)
# (800, 800, 3)
# (284, 284, 3)
# (1390, 1100, 3)
# (900, 900, 3)
# (750, 750, 3)
# (657, 700, 3)
# (630, 799, 3)
# (750, 750, 3)
# (640, 640, 3)
# (310, 310, 3)
# (640, 640, 3)
# (800, 800, 3)
# (478, 400, 3)
# (681, 900, 3)
# (667, 650, 3)
# ../data/validation/pic_6129.png
# (800, 800, 3)
# (310, 310, 3)
# (800, 800, 3)
# (360, 359, 3)
# (800, 800, 3)
# (466, 700, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (1000, 1000, 3)
# (800, 800, 3)
# (800, 800, 3)
# (600, 600, 3)
# (676, 610, 3)
# (800, 800, 3)
# (500, 500, 3)
# (400, 400, 3)
# (400, 600, 3)
# (519, 527, 3)
# (800, 800, 3)
# (460, 460, 3)
# (800, 800, 3)
# (750, 750, 3)
# ../data/validation/pic_5954.png
# (310, 310, 3)
# (800, 800, 3)
# (300, 300, 3)
# ../data/validation/pic_2354.png
# (709, 269, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (350, 350, 3)
# ../data/validation/pic_1198.png
# (800, 800, 3)
# (350, 350, 3)
# (718, 960, 3)
# (682, 1023, 3)
# (500, 500, 3)
# (800, 800, 3)
# (800, 800, 3)
# (1024, 668, 3)
# (420, 600, 3)
# (800, 800, 3)
# (600, 600, 3)
# (585, 670, 3)
# (800, 800, 3)
# (4032, 3024, 4)
# (800, 800, 3)
# (347, 400, 4)
# (1200, 780, 3)
# (1200, 1600, 3)
# (364, 547, 3)
# (1000, 1000, 3)
# (310, 310, 3)
# (800, 800, 3)
# (333, 500, 3)
# (350, 350, 3)
# (2304, 2304, 3)
# (1000, 1070, 3)
# (512, 790, 3)
# (800, 800, 3)
# (300, 300, 4)
# (310, 310, 3)
# (260, 350, 3)
# (1767, 1920, 3)
# (800, 800, 3)
# (300, 300, 3)
# (800, 800, 3)
# (412, 550, 3)
# (800, 800, 3)
# (517, 690, 3)
# (800, 800, 3)
# (800, 800, 3)
# (424, 436, 3)
# (500, 500, 3)
# (800, 800, 3)
# (736, 800, 3)
# (800, 800, 3)
# (460, 460, 3)
# (800, 800, 3)
# (800, 800, 3)
# (469, 600, 3)
# (1200, 900, 3)
# (800, 800, 3)
# (800, 800, 3)
# (324, 420, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (640, 427, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (533, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (600, 600, 3)
# (685, 746, 3)
# (400, 400, 3)
# (928, 750, 3)
# (598, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (800, 800, 3)
# (350, 350, 3)
# (553, 800, 3)
# (468, 468, 3)
# ../data/validation/pic_2890.png
# (800, 800, 3)
# (1767, 1440, 3)
# (800, 800, 3)
# (800, 800, 3)
# (400, 400, 3)
# (688, 1024, 3)
# (800, 800, 3)
# (800, 800, 3)

# %%
pd.DataFrame(widths).describe()
# Out:
#                  0
# count  6190.000000
# mean    716.451858
# std     319.646995
# min       1.000000
# 25%     502.000000
# 50%     800.000000
# 75%     800.000000
# max    5792.000000

# %%
plt.hist(widths, bins=50)
plt.show()

# %%
paths = [os.path.join('../data/validation', filename) for filename in os.listdir('../data/validation')]

# %%
np.load('../data/resized-validation/pic_1.npy').shape
# Out:
# (300, 300, 3)

# %%
pics = np.array([np.load(path) for path in paths])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-65-d1f0d6ce6158> in <module>()
# ----> 1 pics = np.array([np.load(path) for path in paths])
#
# MemoryError:

# %%
pics.shape

# %%
resize_images('../data/validation', '../data/resized-validation', (300, 300))
# Out:
# /home/mariosk/anaconda2/envs/ipykernel_py3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# 5347
# 4389
# 1136
# 4143
# 5444
# 1860
# 4620
# 1753
# 4527
# 5878
# 6294
# 2099
# 1091
# 1896
# 599
# 2564
# 61
# 5687
# 3372
# 2292
# 4984
# 5535
# 4159
# 3768
# 2147
# 112
# 1015
# 2792
# 2182
# 2814
# 2435
# 4291
# 1353
# 2051
# 4542
# 367
# 2212
# 5254
# 4669
# 4950
# 3353
# 1509
# 1101
# 6042
# 5060
# 3424
# 130
# 5872
# 1177
# 5390
# 2803
# 3724
# 3396
# 2434
# 2899
# 4035
# 324
# 769
# 4130
# 4456
# 757
# 5586
# 1776
# 2726
# 2469
# 452
# 1410
# 1599
# 5725
# 465
# 3663
# 1299
# 2200
# 1520
# 6073
# 1232
# 1434
# 594
# 2902
# 1127
# 1102
# 1133
# 1522
# 5368
# 1263
# 508
# 3974
# 1205
# 1902
# 2763
# 2072
# 4695
# 3638
# 5253
# 1629
# 4680
# 6340
# 4303
# 2877
# 1190
# 6014
# 5568
# 1225
# 121
# 1241
# 4753
# 6303
# 3659
# 1361
# 2697
# 613
# 1111
# 3199
# 1912
# 1693
# 559
# 2807
# 1457
# 1677
# 3330
# 5573
# 1158
# 261
# 6381
# 2464
# 1948
# 4963
# 910
# 3029
# 1207
# 466
# 4657
# 5178
# 4330
# 4344
# 411
# 4761
# 430
# 6146
# 3305
# 4932
# 3957
# 6183
# 5403
# 3555
# 360
# 4105
# 3324
# 972
# 3535
# /home/mariosk/anaconda2/envs/ipykernel_py3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 19398656 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /home/mariosk/anaconda2/envs/ipykernel_py3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 19988480 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /home/mariosk/anaconda2/envs/ipykernel_py3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 40108032 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /home/mariosk/anaconda2/envs/ipykernel_py3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 34865152 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /home/mariosk/anaconda2/envs/ipykernel_py3/lib/python3.6/site-packages/PIL/TiffImagePlugin.py:709: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 10.
#   warnings.warn(str(msg))
# 2031
# 6035
# 5012
# 848
# 4937
# 5201
# 721
# 2575
# 3483
# 1956
# 5172
# 4202
# 3445
# 3023
# 698
# 3248
# 6377
# 4604
# 459
# 1148
# 2039
# 5737
# 5524
# 1518
# 3622
# 716
# 1366
# 5187
# 6215
# 64
# 6060
# 5493
# 4752
# 2424
# 2013
# 2032
# 879
# 5380
# 6192
# 5675
# 671
# 6322
# 3015
# 5233
# 1065
# 4339
# 1686
# 5539
# 5861
# 4741
# 5503
# 2050
# 5036
# 5222
# 157
# 4841
# 4748
# 1185
# 6129
# 5954
# 2354
# 1198
# 2890

# %%
min([i.shape[0] for i in images])
# Out:
# 276

# %%
min([i.shape[1] for i in images])
# Out:
# 284

# %%
plt.hist([i.shape[0] for i in images])
plt.show()

# %%
plt.hist([i.shape[1] for i in images])
plt.show()

# %%
plt.clf()

plt.figure(figsize=(10, 100))
for i, image in enumerate(images[:10]):
    plt.subplot(10, 1, i + 1)
    plt.imshow(resize(image, (300, 300)))
plt.show()
# Out:
# /home/mariosk/anaconda2/envs/ipykernel_py3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-9a4713f119b4> in <module>()
#       4 for i, image in enumerate(images[:10]):
#       5     plt.subplot(10, 1, i + 1)
# ----> 6     plt.imshow(resize(image, (300, 300)))
#       7 plt.show()
#
# ~/anaconda2/envs/ipykernel_py3/lib/python3.6/site-packages/skimage/transform/_warps.py in resize(image, output_shape, order, mode, cval, clip, preserve_range)
#      86
#      87     rows, cols = output_shape[0], output_shape[1]
# ---> 88     orig_rows, orig_cols = image.shape[0], image.shape[1]
#      89
#      90     row_scale = float(orig_rows) / rows
#
# AttributeError: 'str' object has no attribute 'shape'
